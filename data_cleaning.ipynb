# %%
## Import dependencies
import pandas as pd
import numpy as np
import requests 
import matplotlib as plt
import plotly.express as px

# %%
# Read in CSV files as Pandas DataFrames.
netflix1_df = pd.read_csv('/Users/linagarcia/Desktop/Analysis Projects/Netflix_Team_1/Resources/netflix_list.csv', low_memory=False)
netflix2_df = pd.read_csv('/Users/linagarcia/Desktop/Analysis Projects/Netflix_Team_1/Resources/netflix_titles.csv', low_memory=False)

# %%
netflix1_df
# Out:
#         imdb_id                  title popular_rank certificate  startYear  \
# 0     tt4052886                Lucifer            1          15     2016.0
# 1     tt0993840       Army of the Dead            2          18     2021.0
# 2     tt7255502    The Kominsky Method            3          18     2018.0
# 3     tt0108778                Friends            4         13+     1994.0
# 4     tt9251798               Ragnarok            5          18     2020.0
# ...         ...                    ...          ...         ...        ...
# 7003  tt9777386   Merry Happy Whatever       16,543          13     2019.0
# 7004  tt9790434       The Morning Show       16,569         NaN     2019.0
# 7005  tt9817600                 Losers       16,599          16     2019.0
# 7006  tt9842922           Firefly Lane       16,627          18     2021.0
# 7007  tt9865968         Medical Police       16,648         NaN     2020.0
#
# ...

# %%
#Drop unused Columns
netflix1_df_dropped = netflix1_df.drop(columns=['imdb_id','plot','summary','isAdult','image_url','cast','endYear'])
netflix1_df_dropped.head()
# Out:
#                  title popular_rank certificate  startYear  episodes runtime  \
# 0              Lucifer            1          15     2016.0      93.0      42
# 1     Army of the Dead            2          18     2021.0       NaN     148
# 2  The Kominsky Method            3          18     2018.0      22.0      30
# 3              Friends            4         13+     1994.0     235.0      22
# 4             Ragnarok            5          18     2020.0      12.0      45
#
#        type  orign_country   language  rating  numVotes                genres
# 0  tvSeries  United States    English     8.1  250884.0   Crime,Drama,Fantasy
# 1     movie  United States    English     5.8  110780.0   Action,Crime,Horror
# 2  tvSeries  United States    English     8.2   28795.0          Comedy,Drama
# 3  tvSeries  United States    English     8.9  861843.0        Comedy,Romance
# 4  tvSeries         Norway  Norwegian     7.5   26606.0  Action,Drama,Fantasy

# %%
#Check for null columns
netflix1_df_dropped.isnull().sum()
# Out:
# title               0
# popular_rank        0
# certificate      4599
# startYear         515
# episodes         4704
# runtime             2
# type                2
# orign_country       0
# language            0
# rating           1008
# numVotes         1008
# genres              2
# dtype: int64

# %%
#Count of total number of values in each column
netflix1_df_dropped.count()
# Out:
# title            7008
# popular_rank     7008
# certificate      2409
# startYear        6493
# episodes         2304
# runtime          7006
# type             7006
# orign_country    7008
# language         7008
# rating           6000
# numVotes         6000
# genres           7006
# dtype: int64

# %%
#Look at missing data
netflix1_df_dropped[netflix1_df_dropped['runtime'].isnull()]
# Out:
#                   title popular_rank certificate  startYear  episodes runtime  \
# 6624  The War Next-Door        9,751         NaN        NaN       NaN     NaN
# 6625          Exception        9,752         NaN        NaN       NaN     NaN
#
#      type orign_country language  rating  numVotes genres
# 6624  NaN        Mexico  Spanish     NaN       NaN    NaN
# 6625  NaN             -        -     NaN       NaN    NaN

# %%
#Look at missing data
netflix1_df_dropped[netflix1_df_dropped['genres'].isnull()]
# Out:
#                   title popular_rank certificate  startYear  episodes runtime  \
# 6624  The War Next-Door        9,751         NaN        NaN       NaN     NaN
# 6625          Exception        9,752         NaN        NaN       NaN     NaN
#
#      type orign_country language  rating  numVotes genres
# 6624  NaN        Mexico  Spanish     NaN       NaN    NaN
# 6625  NaN             -        -     NaN       NaN    NaN

# %%
#Look at missing data
netflix1_df_dropped[netflix1_df_dropped['rating'].isnull()]
# Out:
#                                   title popular_rank certificate  startYear  \
# 152                       Don't Look Up          153         NaN     2021.0
# 167   Hotel Transylvania: Transformania          168         NaN     2021.0
# 173                         The Sandman          174         NaN     2021.0
# 251        Army of the Dead: Lost Vegas          252         NaN     2021.0
# 289                        The Ice Road          290       PG-13     2021.0
# ...                                 ...          ...         ...        ...
# 6975                   Ponysitters Club       16,062         NaN     2018.0
# 6979                 Maya and the Three       16,141         NaN     2021.0
# 6984                       Cowboy Bebop       16,217         NaN     2021.0
# 7001                      Pieces of Her       16,513         NaN     2021.0
# 7004                   The Morning Show       16,569         NaN     2019.0
#
# ...

# %%
#Drop rows with missing data
netflix1_df_dropped_data = netflix1_df_dropped.dropna(subset=['rating','genres','runtime','type'])
netflix1_df_dropped_data
# Out:
#                       title popular_rank certificate  startYear  episodes  \
# 0                   Lucifer            1          15     2016.0      93.0
# 1          Army of the Dead            2          18     2021.0       NaN
# 2       The Kominsky Method            3          18     2018.0      22.0
# 3                   Friends            4         13+     1994.0     235.0
# 4                  Ragnarok            5          18     2020.0      12.0
# ...                     ...          ...         ...        ...       ...
# 7002                   Ares       16,535          18     2020.0       NaN
# 7003   Merry Happy Whatever       16,543          13     2019.0       NaN
# 7005                 Losers       16,599          16     2019.0       NaN
# 7006           Firefly Lane       16,627          18     2021.0       NaN
# 7007         Medical Police       16,648         NaN     2020.0       NaN
#
#      runtime       type  orign_country   language  rating  numVotes  \
# ...

# %%
netflix1_df_dropped_data.value_counts(['certificate'])
# Out:
# certificate
# 18             613
# 16             415
# 13             255
# R              226
# A              147
# UA             110
# 7              106
# U              104
# PG-13           92
# 16+             74
# 18+             57
# PG              53
# 13+             21
# All             19
# 15+             18
# Not Rated       16
# 12+             12
# 15              11
# G                7
# 7+               6
# (Banned)         3
# 12               3
# Unrated          2
# NC-17            1
# dtype: int64

# %%
netflix1_df_dropped_data.value_counts(['type'])
# Out:
# type
# movie           2517
# tvSeries        1880
# tvEpisode        639
# tvSpecial        366
# tvMiniSeries     277
# tvMovie          147
# short             85
# video             83
# tvShort            5
# videoGame          1
# dtype: int64

# %%
netflix1_df_dropped_data.value_counts(['language'])
# Out:
# language
# English          3400
# Spanish           392
# Japanese          366
# Korean            281
# -                 279
#                  ...
# Min Nan             1
# Hausa               1
# Ibo                 1
# Luxembourgish       1
# Zulu                1
# Length: 70, dtype: int64

# %%
netflix2_df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#Drop unused Columns
netflix2_df_dropped = netflix2_df.drop(columns=['description','cast','listed_in','show_id'])
netflix2_df_dropped.head()
# Out:
#       type                  title         director        country  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1  TV Show          Blood & Water              NaN   South Africa
# 2  TV Show              Ganglands  Julien Leclercq            NaN
# 3  TV Show  Jailbirds New Orleans              NaN            NaN
# 4  TV Show           Kota Factory              NaN          India
#
#            date_added  release_year rating   duration
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons

# %%
#Check for null columns
netflix2_df_dropped.isnull().sum()
# Out:
# type               0
# title              0
# director        2634
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# dtype: int64

# %%
netflix2_df_dropped[netflix2_df_dropped['duration'].isnull()]
# Out:
#        type                                 title    director        country  \
# 5541  Movie                       Louis C.K. 2017  Louis C.K.  United States
# 5794  Movie                 Louis C.K.: Hilarious  Louis C.K.  United States
# 5813  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.  United States
#
#               date_added  release_year  rating duration
# 5541       April 4, 2017          2017  74 min      NaN
# 5794  September 16, 2016          2010  84 min      NaN
# 5813     August 15, 2016          2015  66 min      NaN

# %%
netflix2_df_dropped[netflix2_df_dropped['date_added'].isnull()]
# Out:
#          type                                        title director  \
# 6066  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6174  TV Show              Anthony Bourdain: Parts Unknown      NaN
# 6795  TV Show                                      Frasier      NaN
# 6806  TV Show                                      Friends      NaN
# 6901  TV Show                              Gunslinger Girl      NaN
# 7196  TV Show                                     Kikoriki      NaN
# 7254  TV Show                          La Familia P. Luche      NaN
# 7406  TV Show                                        Maron      NaN
# 7847  TV Show                                 Red vs. Blue      NaN
# 8182  TV Show                 The Adventures of Figaro Pho      NaN
#
#              country date_added  release_year rating    duration
# 6066  United Kingdom        NaN          2013  TV-MA   2 Seasons
# 6174   United States        NaN          2018  TV-PG   5 Seasons
# ...

# %%
# LG Viewing columns in Netflix2. 
print(netflix2_df_dropped.columns)
# Out:
# Index(['type', 'title', 'director', 'country', 'date_added', 'release_year',
#        'rating', 'duration'],
#       dtype='object')

# %%
# Viewing columns in Netflix1
print(netflix1_df_dropped.columns)
# Out:
# Index(['title', 'popular_rank', 'certificate', 'startYear', 'episodes',
#        'runtime', 'type', 'orign_country', 'language', 'rating', 'numVotes',
#        'genres'],
#       dtype='object')

# %%
# Viewing unique values in "Type" column Nextfix1
netflix1_df_dropped.type.unique()
# Out:
# array(['tvSeries', 'tvMiniSeries', 'movie'], dtype=object)

# %%
# Viewing unique values in "Type" column Nextfix1
netflix2_df_dropped.type.unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
# I think Pandas interprets values that listed as "-" different than "NaN", looks like they're still some null
# values. Should we delete?
netflix1_df_dropped.isna().sum()
# Out:
# title               0
# popular_rank        0
# certificate      4599
# startYear         515
# episodes         4704
# runtime             2
# type                2
# orign_country       0
# language            0
# rating           1008
# numVotes         1008
# genres              2
# dtype: int64

# %%
# Deleted NaN's in Netflix1
netflix1_df_dropped = netflix1_df_dropped.dropna()
netflix1_df_dropped.head()
# Out:
#                  title popular_rank certificate  startYear  episodes runtime  \
# 0              Lucifer            1          15     2016.0      93.0      42
# 2  The Kominsky Method            3          18     2018.0      22.0      30
# 3              Friends            4         13+     1994.0     235.0      22
# 4             Ragnarok            5          18     2020.0      12.0      45
# 5              StartUp            6          18     2016.0      30.0      44
#
#        type  orign_country   language  rating  numVotes                genres
# 0  tvSeries  United States    English     8.1  250884.0   Crime,Drama,Fantasy
# 2  tvSeries  United States    English     8.2   28795.0          Comedy,Drama
# 3  tvSeries  United States    English     8.9  861843.0        Comedy,Romance
# 4  tvSeries         Norway  Norwegian     7.5   26606.0  Action,Drama,Fantasy
# 5  tvSeries  United States    English     8.0   16980.0        Crime,Thriller

# %%
# Checking that there are no more NaN's
netflix1_df_dropped.isna().sum()
# Out:
# title            0
# popular_rank     0
# certificate      0
# startYear        0
# episodes         0
# runtime          0
# type             0
# orign_country    0
# language         0
# rating           0
# numVotes         0
# genres           0
# dtype: int64

# %%
# Viewing NaN's in Netflix2
netflix2_df_dropped.isna().sum()
# Out:
# type               0
# title              0
# director        2634
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# dtype: int64

# %%
# Deleted NaN's in Netflix1
netflix2_df_dropped = netflix2_df_dropped.dropna()
netflix2_df_dropped
# Out:
#          type                          title             director  \
# 0       Movie           Dick Johnson Is Dead      Kirsten Johnson
# 7       Movie                        Sankofa         Haile Gerima
# 8     TV Show  The Great British Baking Show      Andy Devonshire
# 9       Movie                   The Starling       Theodore Melfi
# 12      Movie                   Je Suis Karl  Christian Schwochow
# ...       ...                            ...                  ...
# 8801    Movie                        Zinzana      Majid Al Ansari
# 8802    Movie                         Zodiac        David Fincher
# 8804    Movie                     Zombieland      Ruben Fleischer
# 8805    Movie                           Zoom         Peter Hewitt
# 8806    Movie                         Zubaan          Mozez Singh
#
#                                                 country          date_added  \
# 0                                         United States  September 25, 2021
# ...

# %%
# Checking that there are no more NaN's
netflix2_df_dropped.isna().sum()
# Out:
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# dtype: int64

# %%
# Viewing unique values in "Type" column Nextfix2
netflix2_df_dropped.type.unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
# Viewing unique values in "Type" column Nextfix1.
# Suggest renaming to align with Movie or TV Show like in Netflix2
netflix1_df_dropped.type.unique()
# Out:
# array(['tvSeries', 'tvMiniSeries', 'movie'], dtype=object)

# %%
# Renamed "Type" in N1 to align with Netflix2
netflix1_df_dropped['type'].replace(['tvSeries'],['TV Show'],inplace=True)
netflix1_df_dropped['type'].replace(['tvMiniSeries'],['TV Show'],inplace=True)
netflix1_df_dropped['type'].replace(['movie'],['Movie'],inplace=True)

# %%
netflix1_df_dropped.type.unique()
# Out:
# array(['TV Show', 'Movie'], dtype=object)
